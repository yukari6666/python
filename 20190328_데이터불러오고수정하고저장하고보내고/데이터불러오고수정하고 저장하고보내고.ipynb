# %%
import pandas as pd

# %%
customerData = pd.read_csv('../dataset/customerdata.csv')

# %%
customerData.dtypes
# Out:
# CUSTID           object
# AVERAGEPRICE    float64
# EMI               int64
# DEVICECOUNT     float64
# PRODUCTAGE      float64
# CUSTTYPE         object
# dtype: object

# %%
kopo_customer = pd.read_csv('../dataset/kopo_customerdata.csv')

# %%
kopo_customer.dtypes
# Out:
# CUSTOMERCODE      int64
# STATENAME        object
# ST                int64
# GENDER           object
# DOB               int64
# GENDER1           int64
# EMAIL             int64
# FEST_CNT          int64
# TOTAL_AMOUNT      int64
# AC_AMOUNT         int64
# AV_AMOUNT         int64
# HA_AMOUNT         int64
# EMI_CE_AMOUNT     int64
# IS_HIGHEND        int64
# CNT_VIST          int64
# GAP_VISIT         int64
# dtype: object

# %%
targetGender = 'Male'

# %%
targetGender = targetGender.upper()

# %%
kopo_customer2 = kopo_customer[(kopo_customer.GENDER == 'MALE') & (kopo_customer.EMAIL > 0)]

# %%
kopo_customer.head(100)
# Out:
#     CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0        1503989    State2   2    Male    0        1      1         0
# 1        1190338    State2   2    Male    0        1      0         1
# 2        1424715    State2   2  Female    0        2      0         0
# 3        2483305    State2   2    Male    0        1      0         1
# 4        1178802    State2   2    Male    0        1      0         1
# 5         859044    State2   2    Male    0        1      0         0
# 6         734198    State2   2  Female    0        2      0         0
# 7        1443485    State2   2  Female    0        2      0         0
# 8        2340520    State2   2    Male    0        1      0         1
# 9         697949    State2   2    Male    0        1      0         1
# 10        385031    State2   2    Male    0        1      0         1
# 11       1944258    State2   2  Female    0        2      0         0
# ...

# %%
lowstr = "sss"

# %%
lowstr.upper()
# Out:
# 'SSS'

# %%
kopoVolume = pd.read_csv('../dataset/kopo_product_volume.csv')

# %%
kopoVolume.dtypes
# Out:
# REGIONID        object
# PRODUCTGROUP    object
# YEARWEEK         int64
# VOLUME           int64
# dtype: object

# %%
kopoVolume[(kopoVolume.PRODUCTGROUP == 'ST0002') & (kopoVolume.VOLUME > 300000)]
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME
# 80       A01       ST0002    201452   422468
# 86       A01       ST0002    201451   356271
# 90       A01       ST0002    201449   669711
# 94       A01       ST0002    201447   378339
# 102      A01       ST0002    201448  1400339
# 196      A01       ST0002    201552   422468
# 208      A01       ST0002    201551   356271
# 212      A01       ST0002    201549   669711
# 216      A01       ST0002    201547   378339
# 224      A01       ST0002    201548  1400339
